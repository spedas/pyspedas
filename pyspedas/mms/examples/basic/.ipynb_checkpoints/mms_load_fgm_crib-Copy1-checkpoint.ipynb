# %%
from pytplot import tplot, options

# %%
from pyspedas.mms.fgm import mms_load_fgm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3a91976ec577> in <module>()
# ----> 1 from pyspedas.mms.fgm import mms_load_fgm
#
# ModuleNotFoundError: No module named 'pyspedas'
