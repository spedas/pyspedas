# %%
from pyspedas.mth5.load_fdsn import load_fdsn
import pytplot
# Out:
# 27-Nov-23 17:52:36: loguru synchronized with pyspedas logging

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
load_fdsn(network="4P", station="ALW48", trange=['2015-06-22', '2015-06-24'], nodownload=True)
# Out:
# 2023-11-27T17:52:37.766757-0800 | INFO | mth5.mth5 | close_mth5 | Flushing and closing c:\work\Data\SPEDAS\mth5\4P_ALW48_20150622_20150624.h5

# %%
pytplot.tplot('fdsn_4P_ALW48')
